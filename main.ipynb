# %% [markdown]
# Ideas for data analysis:
# * Total distance
# * Total time
# * Percentage of distance in each sport type
# * Percentage of time in each sport type
# * Number of activities per month over time
# * Distance per month over time
# * Time per month over time

# %%
import pandas as pd
import json

# %%
def read_datastore(file_name):
    try:
        with open(file_name, 'r') as file:
            return json.load(file)
    except FileNotFoundError:
        print(f'Error reading datastore: File not found: {file_name}')
        return None
    except json.JSONDecodeError:
        print(f'Error reading datastore: Invalid JSON format in file: {file_name}')
        return None

# %%
data = read_datastore('data.json')['data']
df = pd.DataFrame(data)
df
# Out:
#       resource_state                                 athlete  \
# 0                  2  {'id': 120371207, 'resource_state': 1}
# 1                  2  {'id': 120371207, 'resource_state': 1}
# 2                  2  {'id': 120371207, 'resource_state': 1}
# 3                  2  {'id': 120371207, 'resource_state': 1}
# 4                  2  {'id': 120371207, 'resource_state': 1}
# ...              ...                                     ...
# 1611               2  {'id': 120371207, 'resource_state': 1}
# 1612               2  {'id': 120371207, 'resource_state': 1}
# 1613               2  {'id': 120371207, 'resource_state': 1}
# 1614               2  {'id': 120371207, 'resource_state': 1}
# 1615               2  {'id': 120371207, 'resource_state': 1}
#
#                      name  distance  moving_time  elapsed_time  \
# 0                 Run 281    5067.1         1691          1691
# 1          Warmup Run 281     867.6          368           368
# 2                Walk 257    4374.4         3756          4918
# 3                 Run 280    5060.0         1769          1769
# 4          Warmup Run 280     838.7          347           347
# ...                   ...       ...          ...           ...
# 1611  Run 3/24, ST&F 2022    3910.7         1201          1201
# 1612   Run 10/19, XC 2021    6662.7         2213          2213
# 1613   Run 10/14, XC 2021    5841.9         1869          1869
# 1614   Run 10/13, XC 2021    6566.1         2100          2100
# 1615  Random Run, XC 2021     273.6          227           227
#
#       total_elevation_gain  type sport_type  workout_type  ...  \
# 0                     10.6   Run        Run           3.0  ...
# 1                      0.0   Run        Run           0.0  ...
# 2                     11.9  Walk       Walk           NaN  ...
# 3                     10.6   Run        Run           3.0  ...
# 4                      0.0   Run        Run           0.0  ...
# ...                    ...   ...        ...           ...  ...
# 1611                  20.1   Run        Run           0.0  ...
# 1612                   0.0   Run        Run           0.0  ...
# 1613                   0.0   Run        Run           2.0  ...
# 1614                   0.0   Run        Run           2.0  ...
# 1615                   0.0   Run        Run           0.0  ...
#
#       display_hide_heartrate_option elev_high elev_low     upload_id  \
# 0                              True      26.6     22.3  1.558889e+10
# 1                              True      26.1     24.5  1.558850e+10
# 2                              True      35.1     26.3  1.558484e+10
# 3                              True      26.6     22.3  1.558129e+10
# 4                              True      26.1     24.5  1.558086e+10
# ...                             ...       ...      ...           ...
# 1611                          False       NaN      NaN           NaN
# 1612                          False       NaN      NaN           NaN
# 1613                          False       NaN      NaN           NaN
# 1614                          False       NaN      NaN           NaN
# 1615                          False       NaN      NaN           NaN
#
#       upload_id_str                                      external_id  \
# 0       15588893095  shealth3b103f62-70e9-4dca-baca-e2fbb1910e11.tcx
# 1       15588500845  shealth597ed137-3eaf-4dca-9ec6-d111928bb124.tcx
# 2       15584835856  shealthb3b0109d-89c9-4d0d-8be9-e35179f20188.tcx
# 3       15581291876  shealthbadba460-9782-4613-8d4e-60d98856f40b.tcx
# 4       15580862419  shealthb72f9849-29c3-42cf-90e3-61530bceb374.tcx
# ...             ...                                              ...
# 1611            NaN                                             None
# 1612            NaN                                             None
# 1613            NaN                                             None
# 1614            NaN                                             None
# 1615            NaN                                             None
#
#      from_accepted_tag pr_count  total_photo_count  has_kudoed
# 0                False        0                  0       False
# 1                False        0                  0       False
# 2                False        0                  0       False
# 3                False        0                  0       False
# 4                False        0                  0       False
# ...                ...      ...                ...         ...
# 1611             False        0                  4       False
# 1612             False        0                  3       False
# 1613             False        0                  3       False
# 1614             False        0                  3       False
# 1615             False        0                  3       False
#
# [1616 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1616 entries, 0 to 1615
# Data columns (total 50 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   resource_state                 1616 non-null   int64
#  1   athlete                        1616 non-null   object
#  2   name                           1616 non-null   object
#  3   distance                       1616 non-null   float64
#  4   moving_time                    1616 non-null   int64
#  5   elapsed_time                   1616 non-null   int64
#  6   total_elevation_gain           1616 non-null   float64
#  7   type                           1616 non-null   object
#  8   sport_type                     1616 non-null   object
#  9   workout_type                   1203 non-null   float64
#  10  id                             1616 non-null   int64
#  11  start_date                     1616 non-null   object
#  12  start_date_local               1616 non-null   object
#  13  timezone                       1616 non-null   object
#  14  utc_offset                     1616 non-null   int64
#  15  location_city                  0 non-null      object
#  16  location_state                 0 non-null      object
#  17  location_country               0 non-null      object
#  18  achievement_count              1616 non-null   int64
#  19  kudos_count                    1616 non-null   int64
#  20  comment_count                  1616 non-null   int64
#  21  athlete_count                  1616 non-null   int64
#  22  photo_count                    1616 non-null   int64
#  23  map                            1616 non-null   object
#  24  trainer                        1616 non-null   bool
#  25  commute                        1616 non-null   bool
#  26  manual                         1616 non-null   bool
#  27  private                        1616 non-null   bool
#  28  visibility                     1616 non-null   object
#  29  flagged                        1616 non-null   bool
#  30  gear_id                        1441 non-null   object
#  31  start_latlng                   1616 non-null   object
#  32  end_latlng                     1616 non-null   object
#  33  average_speed                  1616 non-null   float64
#  34  max_speed                      1616 non-null   float64
#  35  average_cadence                861 non-null    float64
#  36  has_heartrate                  1616 non-null   bool
#  37  average_heartrate              106 non-null    float64
#  38  max_heartrate                  106 non-null    float64
#  39  heartrate_opt_out              1616 non-null   bool
#  40  display_hide_heartrate_option  1616 non-null   bool
#  41  elev_high                      1369 non-null   float64
#  42  elev_low                       1369 non-null   float64
#  43  upload_id                      1369 non-null   float64
#  44  upload_id_str                  1369 non-null   object
#  45  external_id                    1369 non-null   object
#  46  from_accepted_tag              1616 non-null   bool
#  47  pr_count                       1616 non-null   int64
#  48  total_photo_count              1616 non-null   int64
#  49  has_kudoed                     1616 non-null   bool
# dtypes: bool(10), float64(11), int64(12), object(17)
# memory usage: 520.9+ KB

# %%
total_distance = df.distance.sum()
total_distance
# Out:
# np.float64(6461525.5)

# %%
dist_by_sport_type = df.groupby(by='sport_type').distance.sum()
dist_by_sport_type
# Out:
# sport_type
# EBikeRide         90493.4
# Elliptical        37256.5
# Run             5359174.7
# StairStepper      30175.4
# Walk             933965.0
# Workout           10460.5
# Name: distance, dtype: float64

# %%
for cat, dist in dist_by_sport_type.items():
    print(f'Percentage of total distance in category {cat}: {dist*100 / total_distance}%')
# Out:
# Percentage of total distance in category EBikeRide: 1.4004959045661896%
# Percentage of total distance in category Elliptical: 0.5765898470879671%
# Percentage of total distance in category Run: 82.93977482561974%
# Percentage of total distance in category StairStepper: 0.46700117487735676%
# Percentage of total distance in category Walk: 14.454249232630902%
# Percentage of total distance in category Workout: 0.16188901521784602%

# %%
non_manual_df = df[df.manual == False]
non_manual_df.total_elevation_gain.idxmax()
# Out:
# np.int64(283)

# %%
non_manual_df.loc[283]
# Out:
# resource_state                                                                   2
# athlete                                     {'id': 120371207, 'resource_state': 1}
# name                                                                  Solo Run 200
# distance                                                                   19970.2
# moving_time                                                                   6311
# elapsed_time                                                                  6314
# total_elevation_gain                                                         162.0
# type                                                                           Run
# sport_type                                                                     Run
# workout_type                                                                   2.0
# id                                                                     13064937787
# start_date                                                    2024-12-07T10:39:54Z
# start_date_local                                              2024-12-07T05:39:54Z
# timezone                                              (GMT-05:00) America/New_York
# utc_offset                                                                  -18000
# location_city                                                                 None
# location_state                                                                None
# location_country                                                              None
# achievement_count                                                                0
# kudos_count                                                                     17
# comment_count                                                                    0
# athlete_count                                                                    1
# photo_count                                                                      0
# map                              {'id': 'a13064937787', 'summary_polyline': 'c{...
# trainer                                                                      False
# commute                                                                      False
# manual                                                                       False
# private                                                                      False
# visibility                                                          followers_only
# flagged                                                                      False
# gear_id                                                                  g18564771
# start_latlng                                                [40.74434, -74.179136]
# end_latlng                                                 [40.763057, -74.180794]
# average_speed                                                                3.164
# max_speed                                                                     5.42
# average_cadence                                                               44.2
# has_heartrate                                                                False
# average_heartrate                                                              NaN
# max_heartrate                                                                  NaN
# heartrate_opt_out                                                            False
# display_hide_heartrate_option                                                False
# elev_high                                                                     43.2
# elev_low                                                                      14.0
# upload_id                                                            13932315754.0
# upload_id_str                                                          13932315754
# external_id                      e62530a1-fac2-4847-a8b1-21fe2846483f-activity.fit
# from_accepted_tag                                                            False
# pr_count                                                                         0
# total_photo_count                                                                0
# has_kudoed                                                                   False
# Name: 283, dtype: object

# %%
non_manual_df.iloc[283]
# Out:
# resource_state                                                                   2
# athlete                                     {'id': 120371207, 'resource_state': 1}
# name                                                             Solo Cooldown 177
# distance                                                                    1617.0
# moving_time                                                                    611
# elapsed_time                                                                   611
# total_elevation_gain                                                           6.9
# type                                                                           Run
# sport_type                                                                     Run
# workout_type                                                                   0.0
# id                                                                     12756992970
# start_date                                                    2024-10-27T12:17:59Z
# start_date_local                                              2024-10-27T08:17:59Z
# timezone                                              (GMT-05:00) America/New_York
# utc_offset                                                                  -14400
# location_city                                                                 None
# location_state                                                                None
# location_country                                                              None
# achievement_count                                                                0
# kudos_count                                                                      0
# comment_count                                                                    0
# athlete_count                                                                    1
# photo_count                                                                      0
# map                              {'id': 'a12756992970', 'summary_polyline': '',...
# trainer                                                                      False
# commute                                                                      False
# manual                                                                       False
# private                                                                       True
# visibility                                                                 only_me
# flagged                                                                      False
# gear_id                                                                  g18564771
# start_latlng                                                                    []
# end_latlng                                                                      []
# average_speed                                                                2.646
# max_speed                                                                    3.536
# average_cadence                                                               83.5
# has_heartrate                                                                False
# average_heartrate                                                              NaN
# max_heartrate                                                                  NaN
# heartrate_opt_out                                                            False
# display_hide_heartrate_option                                                False
# elev_high                                                                     26.1
# elev_low                                                                      22.1
# upload_id                                                            13602094578.0
# upload_id_str                                                          13602094578
# external_id                      bd0d8acf-34d3-41a3-a679-dda542a6482f-activity.fit
# from_accepted_tag                                                            False
# pr_count                                                                         0
# total_photo_count                                                                5
# has_kudoed                                                                   False
# Name: 410, dtype: object
